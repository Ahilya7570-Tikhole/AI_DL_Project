# %% [markdown]
# /content/drive/MyDrive/AdProject/ads_dataset.csv

# %%
# =========================
# Gemini 2.5 Flash Ad Script Generator (Updated)
# =========================

# Set Gemini API key
# %env GEMINI_API_KEY=AIzaSyAIi4pRRDxJKwwhBsTUChE3pEKFoIbtjE8

import os
import json
import re
import pandas as pd
import google.generativeai as genai
from datetime import datetime
import glob, shutil

# Configure Gemini API
genai.configure(api_key=os.getenv("GEMINI_API_KEY"))

# ---------- Directories ----------
BASE_OUTPUT_DIR = "/content/drive/MyDrive/AdProject/data/processed"
BASE_SCENE_DIR = "/content/drive/MyDrive/AdProject/data/scene_input"
AD_SCRIPT_BASE = os.path.join(BASE_OUTPUT_DIR, "ad_scripts")
os.makedirs(AD_SCRIPT_BASE, exist_ok=True)

timestamp = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
OUTPUT_DIR = os.path.join(AD_SCRIPT_BASE, timestamp)
SCENE_DIR = os.path.join(BASE_SCENE_DIR, timestamp)
os.makedirs(OUTPUT_DIR, exist_ok=True)
os.makedirs(SCENE_DIR, exist_ok=True)

# ---------- Delete Previous Outputs ----------
delete_prev = input("Do you want to delete previous ad script outputs? (yes/no): ").strip().lower()
if delete_prev == "yes":
    for folder in glob.glob(os.path.join(AD_SCRIPT_BASE, "*")):
        if os.path.isdir(folder) and folder != OUTPUT_DIR:
            shutil.rmtree(folder)
    for folder in glob.glob(os.path.join(BASE_SCENE_DIR, "*")):
        if os.path.isdir(folder) and folder != SCENE_DIR:
            shutil.rmtree(folder)
    print("✅ Old ad script outputs deleted, preprocessing data preserved.")
else:
    print("ℹ️ Previous outputs kept.")

# ---------- Script Parser ----------
def parse_ad_script(raw_script, product, ad_type, text_on_screen):
    structured = {
        "Product": product,
        "AdType": ad_type,
        "Headline": "",
        "AdCopy": "",
        "Scenes": [],
        "Voiceover": {"English": "", "Hindi": ""},
        "TextOnScreen": text_on_screen
    }
    lines = raw_script.splitlines()
    current_section = None
    scene_counter = 0
    for line in lines:
        line = line.strip()
        if not line:
            continue
        if line.lower().startswith("headline:"):
            structured["Headline"] = line.split(":",1)[1].strip()
            current_section = "headline"
        elif line.lower().startswith("ad copy:"):
            structured["AdCopy"] = line.split(":",1)[1].strip()
            current_section = "adcopy"
        elif line.lower().startswith("voiceover:"):
            structured["Voiceover"]["English"] = line.split(":",1)[1].strip()
            current_section = "voiceover"
        elif line.lower().startswith("hindi voiceover:") or line.lower().startswith("(hindi)"):
            structured["Voiceover"]["Hindi"] = line.split(":",1)[1].strip()
            current_section = "voiceover_hindi"
        else:
            scene_match = re.match(r'(scene\s*\d+|step\s*\d+|^\d+\.)[:\-]?\s*(.*)', line, re.I)
            if scene_match:
                scene_counter += 1
                desc = scene_match.group(2).strip() or line
                structured["Scenes"].append({"id": scene_counter, "description": desc, "location": "", "emotion": "", "Voiceover":{"English":"","Hindi":""}})
                current_section = "scenes"
            else:
                if current_section == "adcopy":
                    structured["AdCopy"] += " " + line
                elif current_section == "voiceover":
                    structured["Voiceover"]["English"] += " " + line
                elif current_section == "voiceover_hindi":
                    structured["Voiceover"]["Hindi"] += " " + line
                elif current_section == "scenes" and scene_counter > 0:
                    structured["Scenes"][-1]["description"] += " " + line
    return structured

# ---------- Scene & Script Enrichment ----------
def enrich_ad_script(product, audience, emotion, ad_type="General", text_on_screen="", language="English"):
    model = genai.GenerativeModel("gemini-2.5-flash")
    prompt = f"""
Generate a full advertisement script for the product "{product}".
Target Audience: {audience}
Emotion/Tone: {emotion}
Ad Type: {ad_type}
Text on Screen / Tagline: {text_on_screen}
Language: {language}

Include the following clearly labeled sections:
- Headline: catchy and concise
- Ad Copy: 1-2 sentences, persuasive
- Scenes: At least 3, each with:
    - Scene X: Description of visuals and actions
    - Location: Where it takes place
    - Emotion: How characters feel
    - Voiceover: English & Hindi
- Main Voiceover: English & Hindi
- Text on Screen

Format each section with clear labels (e.g., 'Headline:', 'Ad Copy:', 'Scene 1:', 'Voiceover:', etc.)
"""
    try:
        response = model.generate_content(prompt)
        raw_script = response.text
        print(f"--- Raw script for {product} ---\n{raw_script}\n--- End ---\n")
        structured = parse_ad_script(raw_script, product, ad_type, text_on_screen)
        # Ensure at least 3 scenes
        if len(structured["Scenes"]) < 3:
            for i in range(3 - len(structured["Scenes"])):
                structured["Scenes"].append({"id": len(structured["Scenes"])+1, "description": f"Creative scene for {product}", "location": "Generic location", "emotion": "Neutral", "Voiceover":{"English":"","Hindi":""}})
        return structured, raw_script
    except Exception as e:
        print(f"⚠️ Failed to generate script for {product}: {e}")
        return {
            "Product": product,
            "AdType": ad_type,
            "Headline": "",
            "AdCopy": "",
            "Scenes": [
                {"id":1,"description":f"Creative scene for {product}","location":"Generic location","emotion":"Neutral","Voiceover":{"English":"","Hindi":""}},
                {"id":2,"description":f"Creative scene for {product}","location":"Generic location","emotion":"Neutral","Voiceover":{"English":"","Hindi":""}},
                {"id":3,"description":f"Creative scene for {product}","location":"Generic location","emotion":"Neutral","Voiceover":{"English":"","Hindi":""}}
            ],
            "Voiceover":{"English":"","Hindi":""},
            "TextOnScreen": text_on_screen
        }, ""

# ---------- Generate & Save ----------
def generate_and_save(product, audience, emotion, ad_type="General", text_on_screen="", language="English"):
    structured, raw_script = enrich_ad_script(product, audience, emotion, ad_type, text_on_screen, language)
    txt_path = os.path.join(OUTPUT_DIR, f"{product.lower().replace(' ','_')}_script.txt")
    json_path = os.path.join(OUTPUT_DIR, f"{product.lower().replace(' ','_')}_script.json")
    scene_path = os.path.join(SCENE_DIR, f"{product.lower().replace(' ','_')}_scene.json")

    # Save raw txt
    with open(txt_path, "w", encoding="utf-8") as f:
        f.write(raw_script)
    # Save structured JSON
    with open(json_path, "w", encoding="utf-8") as f:
        json.dump(structured, f, indent=4, ensure_ascii=False)
    # Save scenes separately
    with open(scene_path, "w", encoding="utf-8") as f:
        json.dump(structured["Scenes"], f, indent=4, ensure_ascii=False)

    print(f"✅ Saved script and scenes for '{product}'")
    return structured

# ---------- Run Mode ----------
print(f"Outputs saved to:\n{OUTPUT_DIR}\n{SCENE_DIR}\n")
mode = input("Choose Mode:\n1 = Personalized Input\n2 = Bulk from Dataset\nEnter choice: ").strip()
all_scripts = []

if mode=="1":
    product = input("Product Name: ")
    audience = input("Target Audience: ")
    emotion = input("Emotion/Tone: ")
    ad_type = input("Ad Type (General/Video/Print/etc.): ") or "General"
    text_on_screen = input("Text on Screen / Tagline: ") or ""
    language = input("Language (default English): ") or "English"
    generate_and_save(product, audience, emotion, ad_type, text_on_screen, language)

elif mode=="2":
    dataset_path = input("Dataset path (CSV or Excel): ")
    df = pd.read_csv(dataset_path) if dataset_path.endswith(".csv") else pd.read_excel(dataset_path)
    for idx, row in df.iterrows():
        product = row.get("Product", f"Product_{idx}")
        audience = row.get("TargetAudience", "General Audience")
        emotion = row.get("EmotionTone", "Inspiring")
        ad_type = row.get("AdType", "General")
        text_on_screen = row.get("TextOnScreen", "")
        language = row.get("Language", "English")
        try:
            structured = generate_and_save(product, audience, emotion, ad_type, text_on_screen, language)
            all_scripts.append(structured)
        except Exception as e:
            print(f"❌ Failed for {product}: {e}")
    # Save merged JSON for all scripts
    merged_path = os.path.join(SCENE_DIR, "all_scripts.json")
    with open(merged_path, "w", encoding="utf-8") as f:
        json.dump(all_scripts, f, indent=4, ensure_ascii=False)
    print(f"\n📦 Bulk generation completed! All scripts saved at {merged_path}")
# Out:
# env: GEMINI_API_KEY=AIzaSyAIi4pRRDxJKwwhBsTUChE3pEKFoIbtjE8
# Do you want to delete previous ad script outputs? (yes/no): no
# ℹ️ Previous outputs kept.
# Outputs saved to:
# /content/drive/MyDrive/AdProject/data/processed/ad_scripts/2025-09-02_12-06-45
# /content/drive/MyDrive/AdProject/data/scene_input/2025-09-02_12-06-45
#
# Choose Mode:
# 1 = Personalized Input
# 2 = Bulk from Dataset
# Enter choice: 1
# Product Name: Cadbury Dairy Milk
# Target Audience: Kids and young adults
# Emotion/Tone: Joyful, indulgent
# Ad Type (General/Video/Print/etc.): TV Commercial
# Text on Screen / Tagline: Share the Happiness
# Language (default English): english
# ERROR:tornado.access:503 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 6305.62ms
# ERROR:tornado.access:503 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 2149.22ms
# --- Raw script for Cadbury Dairy Milk ---
# Here is the full advertisement script for Cadbury Dairy Milk:
#
# ---
#
# **Headline:** Unwrap Pure Happiness
#
# **Ad Copy:**
# Experience the smooth, creamy taste of Cadbury Dairy Milk, a moment of pure bliss in every bite. It's more than just chocolate; it's a feeling of joy waiting to be shared.
#
# ---
#
# **Scene 1:**
# *   **Description of visuals and actions:** Two young kids (around 8-10 years old), a boy and a girl, are sitting on a park bench under a sunny sky. The boy unwraps a large Cadbury Dairy Milk bar, its iconic purple wrapper gleaming. He breaks off a square and offers it to the girl. They both take a bite simultaneously, their eyes widening in delight, followed by big, genuine smiles at each other.
# *   **Location:** A vibrant, sunny park
# *   **Emotion:** Joy, friendship, contentment, innocent delight
# *   **Voiceover:**
#     *   **English:** (Warm, friendly) "Looks like someone's found the secret to happiness. And it's even better when shared!"
#     *   **Hindi:** (गर्मजोशी से, दोस्ताना) "लगता है किसी को खुशी का राज़ मिल गया है। और जब इसे बाँटा जाता है तो यह और भी बेहतर हो जाता है!"
#
# **Scene 2:**
# *   **Description of visuals and actions:** A group of three young adults (early 20s) are casually gathered in a cozy cafe. One is laughing while scrolling on a phone, another is sketching in a notebook, and the third takes out a Cadbury Dairy Milk bar from their bag. They break off pieces and share them around. Each person takes a bite, closing their eyes for a moment to savor the taste, then opening them with relaxed, happy smiles, nodding in appreciation.
# *   **Location:** A trendy, comfortable cafe
# *   **Emotion:** Relaxation, shared joy, comfort, indulgence
# *   **Voiceover:**
#     *   **English:** (Smooth, cool) "Long day? Sweet break! That creamy Cadbury taste always hits the spot."
#     *   **Hindi:** (शांत, आधुनिक) "लंबा दिन? मीठा ब्रेक! वह मलाईदार कैडबरी स्वाद हमेशा दिल को छू जाता है।"
#
# **Scene 3:**
# *   **Description of visuals and actions:** A teenager (around 16-18 years old) is sitting by a window seat in their room, soft evening light filtering in. They are alone, looking content and peaceful. They slowly unwrap a small Cadbury Dairy Milk bar, take a deliberate, indulgent bite, and lean back, closing their eyes briefly as a look of pure bliss crosses their face. It's a personal, cherished moment.
# *   **Location:** A cozy bedroom/window seat
# *   **Emotion:** Pure indulgence, bliss, personal contentment
# *   **Voiceover:**
#     *   **English:** (Gentle, introspective) "Sometimes, happiness is just for you. Pure indulgence, pure bliss."
#     *   **Hindi:** (कोमल, आत्मनिरीक्षणात्मक) "कभी-कभी, खुशी सिर्फ आपके लिए होती है। शुद्ध भोग, शुद्ध आनंद।"
#
# ---
#
# **Main Voiceover:**
# *   **English:** (Upbeat, warm, with a touch of magic) "Whether you're sharing with friends or savoring a moment alone, Cadbury Dairy Milk brings a special kind of joy to every occasion. Its rich, creamy taste is an experience you'll want to revisit again and again. Cadbury Dairy Milk!"
# *   **Hindi:** (उत्साहपूर्ण, गर्मजोशी से भरा, जादुई स्पर्श के साथ) "चाहे आप दोस्तों के साथ बाँट रहे हों या अकेले एक पल का आनंद ले रहे हों, कैडबरी डेयरी मिल्क हर मौके पर एक ख़ास तरह की खुशी लाता है। इसका समृद्ध, मलाईदार स्वाद एक ऐसा अनुभव है जिसे आप बार-बार जीना चाहेंगे। कैडबरी डेयरी मिल्क!"
#
# **Text on Screen:**
# Share the Happiness
#
# ---
# --- End ---
#
# ✅ Saved script and scenes for 'Cadbury Dairy Milk'

# %%
# =========================
# Gemini 2.5 Flash Ad Script Generator (Full Updated)
# =========================

# Set Gemini API key
# %env GEMINI_API_KEY=AIzaSyAIi4pRRDxJKwwhBsTUChE3pEKFoIbtjE8

import os
import json
import re
import pandas as pd
import google.generativeai as genai
from datetime import datetime
import glob, shutil

# Configure Gemini API
genai.configure(api_key=os.getenv("GEMINI_API_KEY"))

# ---------- Directories ----------
BASE_OUTPUT_DIR = "/content/drive/MyDrive/AdProject/data/processed"
BASE_SCENE_DIR = "/content/drive/MyDrive/AdProject/data/scene_input"
AD_SCRIPT_BASE = os.path.join(BASE_OUTPUT_DIR, "ad_scripts")
os.makedirs(AD_SCRIPT_BASE, exist_ok=True)

timestamp = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
OUTPUT_DIR = os.path.join(AD_SCRIPT_BASE, timestamp)
SCENE_DIR = os.path.join(BASE_SCENE_DIR, timestamp)
os.makedirs(OUTPUT_DIR, exist_ok=True)
os.makedirs(SCENE_DIR, exist_ok=True)

# ---------- Delete Previous Outputs ----------
delete_prev = input("Do you want to delete previous ad script outputs? (yes/no): ").strip().lower()
if delete_prev == "yes":
    for folder in glob.glob(os.path.join(AD_SCRIPT_BASE, "*")):
        if os.path.isdir(folder) and folder != OUTPUT_DIR:
            shutil.rmtree(folder)
    for folder in glob.glob(os.path.join(BASE_SCENE_DIR, "*")):
        if os.path.isdir(folder) and folder != SCENE_DIR:
            shutil.rmtree(folder)
    print("✅ Old ad script outputs deleted, preprocessing data preserved.")
else:
    print("ℹ️ Previous outputs kept.")

# ---------- Script Parser ----------
def parse_ad_script(raw_script, product, ad_type, text_on_screen):
    structured = {
        "Product": product,
        "AdType": ad_type,
        "Headline": "",
        "AdCopy": "",
        "Scenes": [],
        "Voiceover": {"English": "", "Hindi": ""},
        "TextOnScreen": text_on_screen
    }
    lines = raw_script.splitlines()
    current_section = None
    scene_counter = 0
    for line in lines:
        line = line.strip()
        if not line:
            continue
        if line.lower().startswith("headline:"):
            structured["Headline"] = line.split(":",1)[1].strip()
            current_section = "headline"
        elif line.lower().startswith("ad copy:"):
            structured["AdCopy"] = line.split(":",1)[1].strip()
            current_section = "adcopy"
        elif re.match(r'scene\s*\d+:', line.lower()):
            scene_counter += 1
            structured["Scenes"].append({
                "id": scene_counter,
                "description": "",
                "location": "",
                "emotion": "",
                "Voiceover": {"English": "", "Hindi": ""}
            })
            current_section = "scenes"
        elif line.lower().startswith("description:") and scene_counter>0:
            structured["Scenes"][-1]["description"] = line.split(":",1)[1].strip()
        elif line.lower().startswith("location:") and scene_counter>0:
            structured["Scenes"][-1]["location"] = line.split(":",1)[1].strip()
        elif line.lower().startswith("emotion:") and scene_counter>0:
            structured["Scenes"][-1]["emotion"] = line.split(":",1)[1].strip()
        elif line.lower().startswith("voiceover english:") and scene_counter>0:
            structured["Scenes"][-1]["Voiceover"]["English"] = line.split(":",1)[1].strip()
        elif line.lower().startswith("voiceover hindi:") and scene_counter>0:
            structured["Scenes"][-1]["Voiceover"]["Hindi"] = line.split(":",1)[1].strip()
        elif line.lower().startswith("main voiceover english:"):
            structured["Voiceover"]["English"] = line.split(":",1)[1].strip()
        elif line.lower().startswith("main voiceover hindi:"):
            structured["Voiceover"]["Hindi"] = line.split(":",1)[1].strip()
        elif line.lower().startswith("text on screen:"):
            structured["TextOnScreen"] = line.split(":",1)[1].strip()
        else:
            # Append continuation lines
            if current_section=="adcopy":
                structured["AdCopy"] += " " + line
            elif current_section=="headline":
                structured["Headline"] += " " + line
            elif current_section=="scenes" and scene_counter>0:
                structured["Scenes"][-1]["description"] += " " + line
    return structured

# ---------- Scene & Script Enrichment ----------
def enrich_ad_script(product, audience, emotion, ad_type="General", text_on_screen="", language="English"):
    model = genai.GenerativeModel("gemini-2.5-flash")
    prompt = f"""
Generate a full advertisement script for the product "{product}".
Target Audience: {audience}
Emotion/Tone: {emotion}
Ad Type: {ad_type}
Text on Screen / Tagline: {text_on_screen}
Language: {language}

Format the output EXACTLY as:

Headline: <Catchy headline>
Ad Copy: <1-2 persuasive sentences>
Scene 1:
  Description: <Visuals and actions>
  Location: <Location>
  Emotion: <Character emotions>
  Voiceover English: <English voiceover>
  Voiceover Hindi: <Hindi voiceover>
Scene 2:
  Description: ...
  Location: ...
  Emotion: ...
  Voiceover English: ...
  Voiceover Hindi: ...
Scene 3:
  Description: ...
  Location: ...
  Emotion: ...
  Voiceover English: ...
  Voiceover Hindi: ...
Main Voiceover English: <English>
Main Voiceover Hindi: <Hindi>
Text on Screen: <Text displayed>
"""
    try:
        response = model.generate_content(prompt)
        raw_script = response.text
        print(f"--- Raw script for {product} ---\n{raw_script}\n--- End ---\n")
        structured = parse_ad_script(raw_script, product, ad_type, text_on_screen)
        # Ensure at least 3 scenes with default values if missing
        while len(structured["Scenes"]) < 3:
            structured["Scenes"].append({
                "id": len(structured["Scenes"])+1,
                "description": f"Creative scene for {product}",
                "location": "Generic location",
                "emotion": "Neutral",
                "Voiceover": {"English":"","Hindi":""}
            })
        return structured, raw_script
    except Exception as e:
        print(f"⚠️ Failed to generate script for {product}: {e}")
        return {
            "Product": product,
            "AdType": ad_type,
            "Headline": "",
            "AdCopy": "",
            "Scenes": [
                {"id":1,"description":f"Creative scene for {product}","location":"Generic location","emotion":"Neutral","Voiceover":{"English":"","Hindi":""}},
                {"id":2,"description":f"Creative scene for {product}","location":"Generic location","emotion":"Neutral","Voiceover":{"English":"","Hindi":""}},
                {"id":3,"description":f"Creative scene for {product}","location":"Generic location","emotion":"Neutral","Voiceover":{"English":"","Hindi":""}}
            ],
            "Voiceover":{"English":"","Hindi":""},
            "TextOnScreen": text_on_screen
        }, ""

# ---------- Generate & Save ----------
def generate_and_save(product, audience, emotion, ad_type="General", text_on_screen="", language="English"):
    structured, raw_script = enrich_ad_script(product, audience, emotion, ad_type, text_on_screen, language)
    txt_path = os.path.join(OUTPUT_DIR, f"{product.lower().replace(' ','_')}_script.txt")
    json_path = os.path.join(OUTPUT_DIR, f"{product.lower().replace(' ','_')}_script.json")
    scene_path = os.path.join(SCENE_DIR, f"{product.lower().replace(' ','_')}_scene.json")

    # Save raw txt
    with open(txt_path, "w", encoding="utf-8") as f:
        f.write(raw_script)
    # Save structured JSON
    with open(json_path, "w", encoding="utf-8") as f:
        json.dump(structured, f, indent=4, ensure_ascii=False)
    # Save scenes separately
    with open(scene_path, "w", encoding="utf-8") as f:
        json.dump(structured["Scenes"], f, indent=4, ensure_ascii=False)

    print(f"✅ Saved script and scenes for '{product}'")
    return structured

# ---------- Run Mode ----------
print(f"Outputs saved to:\n{OUTPUT_DIR}\n{SCENE_DIR}\n")
mode = input("Choose Mode:\n1 = Personalized Input\n2 = Bulk from Dataset\nEnter choice: ").strip()
all_scripts = []

if mode=="1":
    product = input("Product Name: ")
    audience = input("Target Audience: ")
    emotion = input("Emotion/Tone: ")
    ad_type = input("Ad Type (General/TV/Video/Print/etc.): ") or "General"
    text_on_screen = input("Text on Screen / Tagline: ") or ""
    language = input("Language (default English): ") or "English"
    generate_and_save(product, audience, emotion, ad_type, text_on_screen, language)

elif mode=="2":
    dataset_path = input("Dataset path (CSV or Excel): ")
    df = pd.read_csv(dataset_path) if dataset_path.endswith(".csv") else pd.read_excel(dataset_path)
    for idx, row in df.iterrows():
        product = row.get("Product", f"Product_{idx}")
        audience = row.get("TargetAudience", "General Audience")
        emotion = row.get("EmotionTone", "Inspiring")
        ad_type = row.get("AdType", "General")
        text_on_screen = row.get("TextOnScreen", "")
        language = row.get("Language", "English")
        try:
            structured = generate_and_save(product, audience, emotion, ad_type, text_on_screen, language)
            all_scripts.append(structured)
        except Exception as e:
            print(f"❌ Failed for {product}: {e}")
    # Save merged JSON for all scripts
    merged_path = os.path.join(SCENE_DIR, "all_scripts.json")
    with open(merged_path, "w", encoding="utf-8") as f:
        json.dump(all_scripts, f, indent=4, ensure_ascii=False)
    print(f"\n📦 Bulk generation completed! All scripts saved at {merged_path}")
# Out:
# env: GEMINI_API_KEY=AIzaSyAIi4pRRDxJKwwhBsTUChE3pEKFoIbtjE8
# Do you want to delete previous ad script outputs? (yes/no): no
# ℹ️ Previous outputs kept.
# Outputs saved to:
# /content/drive/MyDrive/AdProject/data/processed/ad_scripts/2025-09-02_12-22-52
# /content/drive/MyDrive/AdProject/data/scene_input/2025-09-02_12-22-52
#
# Choose Mode:
# 1 = Personalized Input
# 2 = Bulk from Dataset
# Enter choice: 2
# Dataset path (CSV or Excel): /content/drive/MyDrive/AdProject/ads_dataset.csv
# --- Raw script for Skybag ---
# Headline: Where Dreams Take Flight.
# Ad Copy: Every journey begins with a dream. Skybag is more than just luggage; it's your partner in every aspiration, built for every path you choose.
#
# Scene 1:
#   Description: A young woman, brightly dressed, confidently pulls her sleek Skybag trolley through a bustling, sunlit airport terminal. She pauses, looking out a large window at planes taking off, a hopeful smile on her face. She checks her boarding pass, then looks forward with determination.
#   Location: Modern Airport Terminal, Departure Gate
#   Emotion: Excitement, Anticipation, Hope
#   Voiceover English: For the spirit that dares to explore, for every new horizon.
#   Voiceover Hindi: उस हौसले के लिए जो नए रास्ते तलाशता है, हर नए क्षितिज के लिए।
#
# Scene 2:
#   Description: A young professional (could be male or female) in smart casuals walks purposefully through a vibrant, modern city square during peak hours. Their stylish Skybag backpack sits comfortably. They glance at their phone, then look up at a towering skyscraper, a look of focus and ambition.
#   Location: Urban Cityscape, Business District
#   Emotion: Confidence, Determination, Ambition
#   Voiceover English: For the ambition that builds tomorrow, for every goal you conquer.
#   Voiceover Hindi: उस लगन के लिए जो कल बनाती है, हर लक्ष्य को जीतने के लिए।
#
# Scene 3:
#   Description: A group of friends (diverse age range) are on a scenic mountain hike. One person, with a durable Skybag duffel slung over their shoulder, reaches a stunning viewpoint. They place their bag down, take out a camera, and capture the breathtaking landscape, sharing a joyful moment with friends.
#   Location: Scenic Mountain Trail / Nature Reserve
#   Emotion: Joy, Freedom, Connection, Wonder
#   Voiceover English: For the moments that refresh your soul, for every story you create.
#   Voiceover Hindi: उन पलों के लिए जो आपकी आत्मा को ताज़ा करते हैं, हर कहानी के लिए जो आप रचते हैं।
#
# Main Voiceover English: From the bustling city to the serene mountains, Skybag is crafted to be your reliable companion. Durable, stylish, and ready for whatever life brings. Your journey awaits. Make every step count with Skybag.
# Main Voiceover Hindi: हलचल भरे शहर से शांत पहाड़ों तक, Skybag आपका विश्वसनीय साथी बनने के लिए बनाया गया है। टिकाऊ, स्टाइलिश और जीवन में आने वाली हर चुनौती के लिए तैयार। आपकी यात्रा इंतज़ार कर रही है। Skybag के साथ हर कदम को महत्वपूर्ण बनाएं।
#
# Text on Screen: Skybag – Where Dreams Take Flight.
# --- End ---
#
# ✅ Saved script and scenes for 'Skybag'
# --- Raw script for Dove ---
# Headline: Beyond Skin Deep: Embrace Your Beautiful.
#
# Ad Copy: Every day, a new opportunity to feel confident and cherished. Dove helps you celebrate the beauty that's uniquely yours.
#
# Scene 1:
#   Description: A young woman, with diverse skin tone, steps out of the shower, gently wraps herself in a towel. She looks at her reflection in the mirror, not critically, but with a soft smile and contentment, touching her freshly moisturized arm. A bottle of Dove body wash/bar is visible on the counter.
#   Location: Modern, clean bathroom with warm lighting.
#   Emotion: Content, confident, self-assured, serene.
#   Voiceover English: "Life is a journey of discovery. Starting with yourself."
#   Voiceover Hindi: "जीवन खोज की यात्रा है। जिसकी शुरुआत आपसे होती है।"
#
# Scene 2:
#   Description: A mother (middle-aged) and her young child (around 5-7 years old) are sitting on a park bench. The child gently traces the lines on the mother's hand, then rests their head on her arm. The mother smiles warmly, looking at her child, then at her own soft, cared-for skin.
#   Location: Sunny, green park with families in the background.
#   Emotion: Loving, gentle, secure, joyful.
#   Voiceover English: "Every touch, every moment, deserves gentleness."
#   Voiceover Hindi: "हर स्पर्श, हर पल, कोमलता का हकदार है।"
#
# Scene 3:
#   Description: A diverse group of friends (men and women, varying ages and body types) are laughing and enjoying a casual outdoor gathering. One person is confidently striking a pose for a photo, another is sharing a heartfelt story, all comfortable and beaming in their own skin. The sun is setting, casting a warm glow.
#   Location: Lively outdoor cafe or rooftop garden.
#   Emotion: Connected, authentic, confident, vibrant, joyful.
#   Voiceover English: "Step out. Embrace who you are, truly."
#   Voiceover Hindi: "बाहर निकलो। आप जो हैं, उसे पूरी तरह अपनाओ।"
#
# Main Voiceover English: "Dove understands that true beauty is unique, real, and radiates from within. It's about feeling confident and comfortable in your own skin, every single day. Celebrate your authentic self. Embrace your beautiful, with Dove."
#
# Main Voiceover Hindi: "डव समझता है कि सच्ची सुंदरता अनूठी, वास्तविक है और भीतर से चमकती है। यह हर दिन अपनी त्वचा में आत्मविश्वास और सहज महसूस करने के बारे में है। अपने प्रामाणिक स्वरूप का जश्न मनाएं। डव के साथ, अपनी सुंदरता को अपनाएं।"
#
# Text on Screen: Dove: Embrace Your Beautiful.
# --- End ---
#
# ✅ Saved script and scenes for 'Dove'
# --- Raw script for Pepsi ---
# Headline: Ignite Your Spark. Refresh Your World.
# Ad Copy: Life's grandest moments and everyday triumphs deserve a celebration that truly refreshes. Reach for the taste that fuels your journey forward.
#
# Scene 1:
#   Description: A young woman, sweat glistening on her forehead, puts down her paint brush, stepping back to admire a vibrant, finished mural on a city wall. She smiles, a look of immense satisfaction. She reaches for a chilled Pepsi bottle from a cooler nearby, takes a long, satisfying sip.
#   Location: Urban alleyway, vibrant street art.
#   Emotion: Satisfaction, accomplishment, relief, joy.
#   Voiceover English: Every stroke, every effort, a piece of your soul on display. This is your masterpiece.
#   Voiceover Hindi: हर स्ट्रोक, हर कोशिश, आपकी आत्मा का एक टुकड़ा। यह आपकी कृति है।
#
# Scene 2:
#   Description: A diverse group of friends (3-4 people) are laughing and high-fiving on a rooftop after successfully setting up a community garden. They look a bit tired but exhilarated. One friend pops open a can of Pepsi, passing it around, and they all take refreshing sips, sharing a moment of collective joy. Sunlight bathes them.
#   Location: City rooftop, community garden.
#   Emotion: Camaraderie, collective triumph, happiness, shared relief.
#   Voiceover English: Together, you built something beautiful. Together, you made a difference.
#   Voiceover Hindi: साथ मिलकर, आपने कुछ खूबसूरत बनाया। साथ मिलकर, आपने बदलाव लाया।
#
# Scene 3:
#   Description: A young man, dressed in smart casuals, looks out from his office window at a bustling city, a thoughtful yet determined expression on his face. He’s just closed a big deal or achieved a significant professional milestone. He turns, picks up a can of Pepsi from his desk, and takes a reflective, confident sip. A slight smile plays on his lips, looking towards future possibilities.
#   Location: Modern office, city skyline view.
#   Emotion: Determination, quiet confidence, forward-looking, reflection, ambition.
#   Voiceover English: Your vision, your drive, shaping tomorrow. The journey continues.
#   Voiceover Hindi: आपकी दृष्टि, आपका जज़्बा, कल को आकार दे रहा है। यात्रा जारी है।
#
# Main Voiceover English: From the quiet moments of creation to the loud cheers of triumph, every step forward deserves a refreshing pause. Embrace your journey, taste the energy, and ignite your spirit. Live your story. Live your refresh. Pepsi.
# Main Voiceover Hindi: रचना के शांत पलों से लेकर जीत के जोशीले जयकारों तक, हर आगे बढ़ा कदम एक ताज़गी भरे विराम का हकदार है। अपनी यात्रा को अपनाओ, ऊर्जा का स्वाद लो, और अपनी आत्मा को प्रज्वलित करो। अपनी कहानी जियो। अपनी ताज़गी जियो। पेप्सी।
#
# Text on Screen: Live Your Story. Live Your Refresh. Pepsi.
# --- End ---
#
# ✅ Saved script and scenes for 'Pepsi'
# --- Raw script for Nike ---
# Headline: Unleash Your Inner Drive.
# Ad Copy: No matter the path, Nike empowers you to find your rhythm and conquer every challenge. Discover unparalleled comfort and performance, propelling you towards your greatest self.
#
# Scene 1:
#   Description: A young woman (20s) in Nike running gear, initially looking tired but determined, pushes through a morning run. Her stride becomes smoother, a faint smile appearing as the sun rises. Close-up on her Nike shoes hitting the pavement.
#   Location: Urban park at dawn.
#   Emotion: Determination, effort, growing exhilaration.
#   Voiceover English: Every journey begins with a single step. Sometimes it's a struggle, sometimes a challenge. But within you, a spark ignites.
#   Voiceover Hindi: हर सफर एक कदम से शुरू होता है। कभी यह मुश्किल होता है, कभी चुनौती भरा। पर आपके भीतर, एक चिंगारी जलती है।
#
# Scene 2:
#   Description: A man (30s-40s) in Nike basketball shorts and a t-shirt, after what appears to be a long day, takes a deep breath before driving towards the hoop. He flawlessly executes a jump shot, the ball swishing through the net. He picks up the ball with a sense of satisfaction.
#   Location: Outdoor basketball court, evening, under floodlights.
#   Emotion: Focus, release, satisfaction, passion.
#   Voiceover English: It's about finding your rhythm, your release. The dedication to chase what makes you feel alive, no matter the day.
#   Voiceover Hindi: यह अपनी ताल, अपनी मुक्ति खोजने के बारे में है। उस जुनून के पीछे भागना जो आपको जीवंत महसूस कराता है, चाहे दिन कैसा भी हो।
#
# Scene 3:
#   Description: A diverse group (a family: mother, father, child, all wearing Nike apparel) are laughing and running freely on a sandy beach. They playfully chase each other, the child leading the way, leaving footprints in the sand as the sun sets.
#   Location: Sandy beach at sunset.
#   Emotion: Joy, connection, freedom, shared experience.
#   Voiceover English: And in those shared moments, those collective triumphs, you realize you're part of something bigger. Together, you rise.
#   Voiceover Hindi: और उन साझा पलों में, उन सामूहिक जीतों में, आप महसूस करते हैं कि आप कुछ बड़े का हिस्सा हैं। साथ मिलकर, आप ऊपर उठते हैं।
#
# Main Voiceover English: From the first step to the last, Nike is with you. Fueling your spirit, supporting every dream. What will you do today? Find your greatness.
# Main Voiceover Hindi: पहले कदम से आखिरी तक, नाइकी आपके साथ है। आपकी आत्मा को ऊर्जा दे रहा है, हर सपने को सहारा दे रहा है। आज आप क्या करेंगे? अपनी महानता खोजें।
# Text on Screen: JUST DO IT.
# --- End ---
#
# ✅ Saved script and scenes for 'Nike'
# --- Raw script for Amul ---
# Headline: The Unsung Hero of Every Indian Dream
#
# Ad Copy: For generations, Amul has been more than just a brand; it's been the pure, wholesome foundation supporting every aspiration, every laugh, and every triumph across India.
#
# Scene 1:
#   Description: A young child (around 5-7 years old) happily drinks a glass of Amul milk, a milk mustache forming. The scene transitions to the child a few years older, energetically playing cricket with friends in a park.
#   Location: A cozy home kitchen, then a sunny neighborhood park.
#   Emotion: Joy, innocence, energy, growth, health.
#   Voiceover English: From the first sips of goodness to the boundless energy of childhood, Amul has always been there, nurturing every moment.
#   Voiceover Hindi: पोषण की पहली घूँट से लेकर बचपन की असीम ऊर्जा तक, अमूल हमेशा साथ रहा है, हर पल को पोषित करता रहा है।
#
# Scene 2:
#   Description: A young woman (early 20s) is seen studying late at night, surrounded by books, a steaming cup of Amul coffee beside her. She then transitions to a modern office setting, confidently presenting her ideas, a small smile of achievement on her face.
#   Location: A quiet study room at night, then a sleek office conference room.
#   Emotion: Determination, focus, ambition, quiet triumph, intellectual growth.
#   Voiceover English: Fuelling late-night studies and powering big dreams, Amul supports every step of your journey towards success.
#   Voiceover Hindi: देर रात की पढ़ाई को शक्ति देता, और बड़े सपनों को उड़ान भरता, अमूल आपकी सफलता की हर यात्रा में साथ देता है।
#
# Scene 3:
#   Description: A multi-generational family (parents, kids, grandparents) gathered around a table, laughing and enjoying a festive meal together – parathas with Amul butter, a bowl of fruit with Amul Dahi, and a special dessert made with Amul cream. A wider shot shows them celebrating a festival (e.g., Diwali or Eid) with Amul sweets, joyfully exchanging them.
#   Location: A warm, inviting dining room; a brightly decorated living room/courtyard during a festival.
#   Emotion: Love, warmth, togetherness, joy, tradition, celebration, belonging.
#   Voiceover English: In shared laughter, festive celebrations, and the warmth of family traditions, Amul brings everyone closer, enriching every memory.
#   Voiceover Hindi: साझा हँसी में, उत्सवों के जश्न में, और परिवार की गर्माहट में, अमूल सबको करीब लाता है, हर याद को समृद्ध करता है।
#
# Main Voiceover English: For generations, Amul has been more than just a brand; it's a legacy of purity, trust, and the unwavering support for every Indian's dream. Join us in celebrating a future built on wholesome goodness, together.
# Main Voiceover Hindi: पीढ़ियों से, अमूल सिर्फ एक ब्रांड नहीं रहा है; यह शुद्धता, विश्वास और हर भारतीय के सपने के लिए अटूट समर्थन की विरासत है। आइए, पौष्टिक अच्छाई पर बने भविष्य का जश्न मनाएं, एक साथ।
#
# Text on Screen: Amul: Nurturing India's Dreams. Every Drop, Every Day.
# अमूल: भारत के सपनों को पोषित करे। हर बूंद, हर दिन।
# --- End ---
#
# ✅ Saved script and scenes for 'Amul'
#
# 📦 Bulk generation completed! All scripts saved at /content/drive/MyDrive/AdProject/data/scene_input/2025-09-02_12-22-52/all_scripts.json

# %%
AIzaSyB3eo_VGTDnQJBau8MpFgq5xyCA2XzNpT4
